# %% [markdown]
# # chat gpt api 요금 체계

# %% [markdown]
# 1) 텍스트 기반 모델 요금 (US$ / 1M tokens)

# %% [markdown]
# | 모델                                                     | 입력 토큰 (Input) | 캐시 입력 (Cached Input) | 출력 토큰 (Output) |
# | ------------------------------------------------------ | ------------: | -------------------: | -------------: |
# | gpt-5.2                                                |          1.75 |                0.175 |          14.00 |
# | gpt-5.1                                                |          1.25 |                0.125 |          10.00 |
# | gpt-5                                                  |          1.25 |                0.125 |          10.00 |
# | gpt-5-mini                                             |          0.25 |                0.025 |           2.00 |
# | gpt-5-nano                                             |          0.05 |                0.005 |           0.40 |
# | gpt-4.1                                                |          2.00 |                 0.50 |           8.00 |
# | gpt-4.1-mini                                           |          0.40 |                 0.10 |           1.60 |
# | gpt-4.1-nano                                           |          0.10 |                0.025 |           0.40 |
# | gpt-4o                                                 |          2.50 |                 1.25 |          10.00 |
# | gpt-4o-mini                                            |          0.15 |                0.075 |           0.60 |
# | Realtime models (text)                                 |        varies |               varies |         varies |
# | *단위: 미국 달러 (USD) / 1,000,000 tokens* ([OpenAI 플랫폼][1]) |               |                      |                |
#
# [1]: https://platform.openai.com/docs/pricing?utm_source=chatgpt.com "Pricing | OpenAI API"

# %% [markdown]
# 2) 이미지 기반 처리 (API 이미지 토큰 요금)

# %% [markdown]
# | 모델                                              |       입력 토큰 |       캐시 입력 | 출력 토큰 |
# | ----------------------------------------------- | ----------: | ----------: | ----: |
# | gpt-image-1.5 / chatgpt-image-latest            |        8.00 |        2.00 | 32.00 |
# | gpt-image-1                                     |       10.00 |        2.50 | 40.00 |
# | gpt-image-1-mini                                |        2.50 |        0.25 |  8.00 |
# | Realtime vision                                 | 5.00 / 0.80 | 0.50 / 0.08 |     — |
# | *영상 입력에서 생성된 텍스트가 아닌 토큰만 과금됨* ([OpenAI 플랫폼][1]) |             |             |       |
#
# [1]: https://platform.openai.com/docs/pricing?utm_source=chatgpt.com "Pricing | OpenAI API"

# %% [markdown]
# 3) 오디오 처리 (Speech / Realtime Audio)

# %% [markdown]
# | 모델                                       | 입력 토큰 | 캐시 입력 | 출력 토큰 |
# | ---------------------------------------- | ----: | ----: | ----: |
# | gpt-realtime (audio)                     | 32.00 |  0.40 | 64.00 |
# | gpt-realtime-mini                        | 10.00 |  0.30 | 20.00 |
# | gpt-4o-realtime-preview                  | 40.00 |  2.50 | 80.00 |
# | gpt-4o-mini-realtime-preview             | 10.00 |  0.30 | 20.00 |
# | *미국 달러 기준 / 1M tokens* ([OpenAI 플랫폼][1]) |       |       |       |
#
# [1]: https://platform.openai.com/docs/pricing?utm_source=chatgpt.com "Pricing | OpenAI API"

# %% [markdown]
# 4) 머신 비전 및 기타

# %% [markdown]
# | 항목                          |     단위 요금 |                   |
# | --------------------------- | --------: | ----------------- |
# | Video 생성 (sora-2)           | $0.10 / 초 |                   |
# | Video 생성 (sora-2-pro 720p)  | $0.30 / 초 |                   |
# | Video 생성 (sora-2-pro 1080p) | $0.50 / 초 | ([OpenAI 플랫폼][1]) |
#
# [1]: https://platform.openai.com/docs/pricing?utm_source=chatgpt.com "Pricing | OpenAI API"

# %% [markdown]
# 5) 파인튜닝 (Fine-Tuning) 요금 (US$ / 1M tokens)

# %% [markdown]
# | 모델                 |  Training | Input | Cached Input | Output |                   |
# | ------------------ | --------: | ----: | -----------: | -----: | ----------------- |
# | gpt-4.1            |     25.00 |  3.00 |         0.75 |  12.00 |                   |
# | gpt-4.1-mini       |      5.00 |  0.80 |         0.20 |   3.20 |                   |
# | gpt-4.1-nano       |      1.50 |  0.20 |         0.05 |   0.80 |                   |
# | o4-mini-2025-04-16 | 100.00/hr |  4.00 |         1.00 |  16.00 |                   |
# | gpt-3.5-turbo      |      8.00 |  3.00 |            — |   6.00 | ([OpenAI 플랫폼][1]) |
#
# [1]: https://platform.openai.com/docs/pricing?utm_source=chatgpt.com "Pricing | OpenAI API"

# %% [markdown]
# 6) 임베딩(Embeddings)

# %% [markdown]
# | 모델                     | Embeddings per 1M tokens |                   |
# | ---------------------- | -----------------------: | ----------------- |
# | text-embedding-3-small |                     0.02 |                   |
# | text-embedding-3-large |                     0.13 |                   |
# | text-embedding-ada-002 |                     0.10 | ([OpenAI 플랫폼][1]) |
#
# [1]: https://platform.openai.com/docs/pricing?utm_source=chatgpt.com "Pricing | OpenAI API"

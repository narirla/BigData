# %%
# %pip install openai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from openai import OpenAI

# %%
apiKey = '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'
client = OpenAI(api_key=apiKey)
completion = client.chat.completions.create(model='gpt-3.5-turbo',
                                            messages=[{'role':'user','content':'hello world'}])

# completion

print(completion.choices[0].message.content) # 답변만 출력
print(completion.usage.total_tokens) # 총 사용된 token 출력
# Out:
# Hello! How can I assist you today?
# 18

# %% [markdown]
# 환경 변수(시스템 변수)
# - OPENAI_API_KEY

# %%
import os
import openai 
from openai import OpenAI
apiKey = os.getenv('OPENAI_API_KEY')
openai.api_key = apiKey

# %%
client = OpenAI()
completion = client.chat.completions.create(model='gpt-4o',
                                            messages=[{'role':'user','content':'인공지능에 대해 간단히 알려줄래'}])

# completion

print(completion.choices[0].message.content) # 답변만 출력
print(completion.usage.total_tokens) # 총 사용된 token 출력
# Out:
# 물론입니다! 인공지능(AI)은 인간의 지능적인 능력을 모방하거나 이를 확장하는 컴퓨터 시스템이나 알고리즘을 말합니다. AI는 다양한 분야에서 활용되고 있으며, 기본적으로는 데이터를 분석하고 학습하여 패턴을 인식하고 예측하는 능력을 갖추고 있습니다. 주요 분야로는 다음과 같은 것들이 있습니다:
#
# 1. **기계 학습(머신 러닝)**: 컴퓨터가 명시적으로 프로그래밍되지 않아도 데이터를 통해 학습하고 예측 모델을 만드는 기술입니다.
#
# 2. **자연어 처리(NLP)**: 인간의 언어를 이해하고 생성하는 기술로, 챗봇, 자동 번역, 감성 분석 등에 활용됩니다.
#
# 3. **컴퓨터 비전**: 이미지나 비디오를 분석하여 객체를 인식하거나 분류하는 기술로, 얼굴 인식, 자율주행차 등에 사용됩니다.
#
# 4. **로보틱스**: 로봇에 AI를 탑재하여 자율적으로 작업을 수행하도록 하는 기술입니다.
#
# 5. **전문가 시스템**: 특정 분야의 전문가 지식을 활용하여 문제를 해결하는 시스템입니다.
#
# AI는 우리의 생활을 편리하게 만들고, 산업 전반에 걸쳐 혁신을 일으키고 있습니다. 그러나 AI의 윤리적 문제와 잠재적 위험성에 대한 논의도 활발하게 이루어지고 있습니다.
# 322

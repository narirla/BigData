# %%
from openai import OpenAI
import openai
import os

api_key = os.getenv('OPENAI_API_KEY')
openai.api_key = api_key

# %%
client = OpenAI()
response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[{'role':'user',
            'content':'인공지능에 대해 알려줘'}] )
print( response.choices[0].message.content)
# Out:
# 인공지능(Artificial Intelligence, AI)이란 인간과 유사한 지능을 가진 컴퓨터 시스템을 의미합니다. 일반적으로 인공지능은 머신 러닝, 딥 러닝, 자연어 처리, 컴퓨터 비전 등의 기술을 이용하여 인간의 학습, 추론, 의사 결정 등의 능력을 모방하고, 이를 토대로 다양한 작업을 수행할 수 있는 기술을 의미합니다.
#
# 인공지능은 다양한 분야에서 활용되고 있으며, 의료, 금융, 자율주행 자동차, 로봇 공학, 게임 등 다양한 산업 분야에서 혁신을 이끌고 있습니다. 또한 인공지능 기술은 새로운 비즈니스 모델을 제안하고 획기적인 변화를 가져다주는 역할을 하고 있습니다.
#
# 인공지능 기술은 계속해서 발전하고 있으며, 더욱 더 다양한 분야에 활용될 것으로 예상됩니다. 또한 인공지능의 발전은 기술적 측면 뿐만 아니라, 윤리적, 법적, 사회적 측면에서도 다양한 고민과 논의가 필요한 분야라고 할 수 있습니다.

# %%
prompt = [{
        "role": "user",
        "content": [
            {"type": "text", "text": "이 이미지에 대해 설명해줘"},
            {"type": "image_url",
                "image_url": {
                    "url": "https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg/2560px-Gfp-wisconsin-madison-the-nature-boardwalk.jpg",
                },
            },
        ],
}]
client = OpenAI()
response = client.chat.completions.create(model='gpt-4o-mini',
            messages=prompt )
print(response.choices[0].message.content)
# Out:
# 이 이미지는 넓은 초원과 푸른 하늘을 배경으로 한 풍경을 보여주고 있습니다. 가운데에는 나무로 만들어진 보도블럭이 길게 이어져 있으며, 이 길은 초원 속으로 뻗어 있습니다. 초원은 푸른 풀과 다양한 색상의 식물로 덮여 있으며, 하늘은 맑고 파란 색조와 함께 흰 구름이 흩어져 있는 모습입니다. 이 장면은 평화롭고 자연의 아름다움을 잘 표현하고 있습니다.

# %%
from openai import OpenAI
import base64

client = OpenAI()

# 로컬 이미지를 인코딩 이미지로 변경해주는 함수
def encode_image(image_path):
    with open(image_path, "rb") as f:
        return base64.b64encode(f.read()).decode("utf-8")

image_base64 = encode_image("image/d.jpg")  # 여기에 본인의 로컬 이미지 경로

data_url = f"data:image/jpeg;base64,{image_base64}"

response = client.chat.completions.create(
    model="gpt-4o",
    messages=[{
        "role": "user",
        "content": [
            {"type": "text", "text": "이 이미지에 대해 설명해줘"},
            {"type": "image_url", "image_url": {"url": data_url}},
        ],
    }]
)
print(response.choices[0].message.content)
# Out:
# 죄송하지만, 이 이미지에 있는 사람이 누군지 알 수 없습니다. 이 이미지는 정장을 입고 있는 한 남성이 묘사되어 있습니다. 더 도와드릴 내용이 있으면 말씀해주세요!

# %% [markdown]
# ## 3분 퀴즈
# 나의 이미지를 4o 모델을 통해서 이미지를 설명하시요.

# %%
from openai import OpenAI
import base64

client = OpenAI()

def encode_image(image_path):
    with open(image_path, "rb") as f:
        return base64.b64encode(f.read()).decode("utf-8")

image_base64 = encode_image("image/명함.png")  # 여기에 본인의 로컬 이미지 경로

data_url = f"data:image/jpeg;base64,{image_base64}"

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{
        "role": "user",
        "content": [
            {"type": "text", "text": "이미지의 글자 추출해 줄래"},
            {"type": "image_url", "image_url": {"url": data_url}},
        ],
    }]
)

print(response.choices[0].message.content)
# Out:
# 이미지에서 추출된 텍스트는 다음과 같습니다:
#
# - 수협중앙회
# - 홍 길 동
# - 서울지점 / 지점장
# - 123-456 서울특별시 00구 00로 서울빌딩
# - Tel 02-2000-0000
# - Fax 02-2000-0000
# - phone 010-0000-0000
# - www.suhyup.co.kr
# - - 수협 명함 A형 -

# %%
seolleung_terrarosa_base64 = encode_image("images/seolleung_terrarosa.jpg")
local_stitch_terrarosa_base64 = encode_image("images/local_stitch_terrarosa.jpg")

messages = [
    {
        "role": "user",
        "content": [
            {"type": "text", "text": "두 카페의 차이점을 설명해주세요."},
            {
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/jpeg;base64,{seolleung_terrarosa_base64}",
                },
            },
            {
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/jpeg;base64,{local_stitch_terrarosa_base64}",
                },
            },
        ],
    }
]

response = client.chat.completions.create(
    model="gpt-4o",  # 응답 생성에 사용할 모델 지정
    messages=messages # 대화 기록을 입력으로 전달
)

response.choices[0].message.content
# Out:
# '두 카페의 차이점은 다음과 같습니다:\n\n1. **인테리어 스타일**:\n   - 첫 번째 카페는 따뜻한 목재 바닥과 톤 다운된 조명으로 모던하고 아늑한 느낌을 줍니다.\n   - 두 번째 카페는 밝은 색상의 타일 바닥과 선명한 노랑 벽면이 있어 보다 현대적이고 활기찬 분위기를 연출합니다.\n\n2. **조명**:\n   - 첫 번째 카페는 조명이 조금 어두워 편안한 분위기를 강조합니다.\n   - 두 번째 카페는 밝은 조명과 넓은 창문을 통해 자연광을 많이 유입시켜 활기 있는 분위기를 제공합니다.\n\n3. **가구 및 레이아웃**:\n   - 첫 번째 카페는 나무 의자와 테이블로 구성되어 있으며 공간이 넓어 보입니다.\n   - 두 번째 카페는 밝은 색상의 가구와 금속 소재의 바가 있어 모던한 느낌을 더합니다.\n\n4. **공간 활용**:\n   - 첫 번째 카페는 좀 더 넓고 대화하기 좋은 자리 배치가 특징입니다.\n   - 두 번째 카페는 효율적인 바 배치로 주문과 서빙이 용이한 구조입니다. \n\n각 카페는 각각 고유의 분위기와 스타일을 가지고 있어 방문 목적에 따라 선택할 수 있습니다.'

# %%
print(response.choices[0].message.content)
# Out:
# 두 카페의 차이점은 다음과 같습니다:
#
# 1. **인테리어 스타일**:
#    - 첫 번째 카페는 따뜻한 목재 바닥과 톤 다운된 조명으로 모던하고 아늑한 느낌을 줍니다.
#    - 두 번째 카페는 밝은 색상의 타일 바닥과 선명한 노랑 벽면이 있어 보다 현대적이고 활기찬 분위기를 연출합니다.
#
# 2. **조명**:
#    - 첫 번째 카페는 조명이 조금 어두워 편안한 분위기를 강조합니다.
#    - 두 번째 카페는 밝은 조명과 넓은 창문을 통해 자연광을 많이 유입시켜 활기 있는 분위기를 제공합니다.
#
# 3. **가구 및 레이아웃**:
#    - 첫 번째 카페는 나무 의자와 테이블로 구성되어 있으며 공간이 넓어 보입니다.
#    - 두 번째 카페는 밝은 색상의 가구와 금속 소재의 바가 있어 모던한 느낌을 더합니다.
#
# 4. **공간 활용**:
#    - 첫 번째 카페는 좀 더 넓고 대화하기 좋은 자리 배치가 특징입니다.
#    - 두 번째 카페는 효율적인 바 배치로 주문과 서빙이 용이한 구조입니다.
#
# 각 카페는 각각 고유의 분위기와 스타일을 가지고 있어 방문 목적에 따라 선택할 수 있습니다.

# %%
oecd_rnd_2021_base64 = encode_image("images/oecd_rnd_2021_large.png")
oecd_rnd_2022_base64 = encode_image("images/oecd_rnd_2022_large.png")

messages = [
    {
        "role": "user",
        "content": [
            {"type": "text", "text": "첫번째는 2021년 데이터이고, 두번째는 2022년 데이터입니다. 이 데이터에 대해 설명해주세요. 어떤 변화가 있었나요? 한국 중심으로 설명해주세요."},
            {
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/jpeg;base64,{oecd_rnd_2021_base64}",
                },
            },
            {
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/jpeg;base64,{oecd_rnd_2022_base64}",
                },
            },
        ],
    }
]

response = client.chat.completions.create(
    model="gpt-4o",  # 응답 생성에 사용할 모델 지정
    messages=messages # 대화 기록을 입력으로 전달
)

response.choices[0].message.content
print(response.choices[0].message.content)
# Out:
# 이 두 데이터는 각 국가의 연구개발비(R&D)와 GDP 대비 연구개발비 비중을 보여줍니다. 한국을 중심으로 살펴보면:
#
# ### 연구개발비 변화
# - **한국의 연구개발비**: 2021년 데이터에서는 약 89,282백만 달러였으며, 2022년에는 약 91,013백만 달러로 증가했습니다.
#
# ### GDP 대비 연구개발비 비중 변화
# - **비중 변화**: 2021년에는 4.93%였고, 2022년에는 5.21%로 증가했습니다.
#
# ### 일반적인 경향
# - 세계적으로 연구개발비와 GDP 대비 연구개발비 비중이 대체로 증가하는 추세입니다.
# - 특히, 한국은 GDP 대비 높은 연구개발비 비율을 유지하며, 이는 기술 발전과 혁신에 대한 지속적인 중요성을 반영하고 있습니다.
#
# 한국의 연구개발 투자가 양적, 질적으로 증가하고 있음을 알 수 있습니다. 이는 국가 경쟁력 강화와 지속 가능한 성장을 위한 긍정적 지표로 볼 수 있습니다.

# %%
oecd_rnd_2021_base64 = encode_image("images/oecd_rnd_2021_medium.png")
oecd_rnd_2022_base64 = encode_image("images/oecd_rnd_2022.png")

messages = [
    {
        "role": "user",
        "content": [
            {"type": "text", "text": "첫번째는 2021년 데이터이고, 두번째는 2022년 데이터입니다. 이 데이터에 대해 설명해주세요. 어떤 변화가 있었나요? 한국 중심으로 설명해주세요."},
            {
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/jpeg;base64,{oecd_rnd_2021_base64}",
                },
            },
            {
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/jpeg;base64,{oecd_rnd_2022_base64}",
                },
            },
        ],
    }
]

response = client.chat.completions.create(
    model="gpt-4o",  # 응답 생성에 사용할 모델 지정
    messages=messages # 대화 기록을 입력으로 전달
)

response.choices[0].message.content
print(response.choices[0].message.content)
# Out:
# 첫 번째 이미지(2021년 데이터)와 두 번째 이미지(2022년 데이터)를 비교하여 설명드리겠습니다.
#
# ### 한국의 연도별 연구개발비 변화:
# 1. **연구개발비**:
#    - 2021년: 121,739 백만 USD
#    - 2022년: 133,867 백만 USD
#    - 증가 추세를 보이며 연구개발비가 약 12,128 백만 USD 상승했습니다.
#
# 2. **GDP 대비 연구개발비 비중**:
#    - 2021년: 4.93%
#    - 2022년: 5.21%
#    - 비중이 증가하여 한국의 GDP 대비 연구개발비 투자 비중이 더 높아졌습니다.
#
# ### 전반적인 글로벌 변화:
# - 미국은 연구개발비가 2021년(720,880 백만 USD)에서 2022년(806,013 백만 USD)으로 증가하였으며, GDP 대비 비중도 소폭 증가했습니다.
# - 중국과 일본 등의 다른 주요 국가들도 연구개발비가 변동되었으며, 대체로 세계 주요 국가들은 연구개발 투자를 증가시키는 경향을 보였습니다.
#
# ### 결론:
# - 한국은 연구개발비와 그 비중 모두 증가하여, 기술 및 과학 분야에 대한 투자가 강화되고 있음을 보여줍니다. 이는 향후 기술 혁신과 경제 성장에 긍정적인 영향을 미칠 것으로 예상됩니다.

# %% [markdown]
# ### stanford_coffee.jpg : 이 이미지에 대해서 설명하시오.

# %%
from openai import OpenAI
import base64

client = OpenAI()

def encode_image(image_path):
    with open(image_path, "rb") as f:
        return base64.b64encode(f.read()).decode("utf-8")

image_base64 = encode_image("images/stanford_coffee.jpg")  # 여기에 본인의 로컬 이미지 경로

data_url = f"data:image/jpeg;base64,{image_base64}"

response = client.chat.completions.create(
    model="gpt-4o",
    messages=[{
        "role": "user",
        "content": [
            {"type": "text", "text": "이 이미지에 대해 설명해줘"},
            {"type": "image_url", "image_url": {"url": data_url}},
        ],
    }]
)

response.choices[0].message.content
print(response.choices[0].message.content)
# Out:
# 이 이미지는 커피숍 창문 너머로 보이는 거리의 모습을 담고 있습니다. 창문에는 "COFFEE & BAKERY"라는 글자가 거꾸로 보입니다. 외부에는 관광 버스가 도로에 주차되어 있고, 여러 사람들이 버스 주변에 모여 있습니다. 일부 사람들은 버스에 탑승하려는 듯 보입니다. 주변에는 나무와 현대식 건물이 보이며, 하늘은 맑은 날씨입니다.

# %% [markdown]
# # chat api 공식 document
#
# https://platform.openai.com/docs/quickstart
#
# https://platform.openai.com/docs/api-reference/introduction

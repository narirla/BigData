# %% [markdown]
# 컨테이너생성
# ```bash
# docker create nginx
# docker ps -a (컨테이너 조회회)
# docker start  컨테이너id(일부입력)
# docker start 59d
# docker ps -a 확인 (create--> up 으로 바뀜: 실행중임을 의미)
# docker create mysql (이미지 없으면 다운로드후 컨테이너 실행)
# ```

# %% [markdown]
# 실행중인 컨테이터 목록조회
#
# ```bash
# docker ps
#
# 실행중이지 않은(중단된) 컨테이터 포함 목록조회
#
# docker ps -a
#
# docker stop 컨테이너아이디
# docker ps (확인)
#
#
# docker run -d nginx
# docker ps (확인)
#
# docker stop (윈도우에서 컴퓨터 종료와 유사)
# docker kill ( 종료 버튼 클릭과 유사)
# docker kill 컨테이너 아이디
#
#
# docker ps -a
# docker rm 컨테이너 아이디
#
# docker run -d nginx
# docker rm 컨테이너 아이디 ( 실행중이라 삭제 불가)
# docker rm 5c
# Error response from daemon: cannot remove container "/inspiring_grothendieck":
#  container is running: stop the container before removing or force remove
#
# docker stop 5c
# docker rm 5c

# %% [markdown]
# ### 여러개 실행후 종료
#
# ```bash
# docker run -d nginx
# docker run -d nginx
# docker stop 5c 6c 여러개 한번에 종료

# %% [markdown]
# ### 중지 컨테이너 모두 삭제
#
# ```bash
# docker rm $(docker ps -qa) 윈도우에서 안됨

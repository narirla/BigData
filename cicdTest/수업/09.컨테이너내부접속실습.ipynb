# %% [markdown]
# ----------------------------------
# 컨테이너 내부접속(일종의 미니컴퓨터로 저장공간이 있음)
# -----------------------------------
# 기존 실행 종료
# ```bash
# docker stop 컨테이너아이디
# docker rm -f 36 5c
#
# docker run -d nginx
# docker ps
# docker exec -it 컨테이너아이디 bash # it(터미널)

# %% [markdown]
# 컨테이너 내부접속
# ```bash
# ls
# pwd
# cat /etc/os-release # 현재 운영체제 종류확인
# cd /etc/nginx
# ls
# cat nginx.conf
# exit # 컨테이너 내부접속 나오기
#
# apt update
# apt install vim # vi 설치
# vi 또는 다른 패키지를 설치하면,
# 그 설치는 컨테이너가 종료되거나 삭제될 때까지 유지

# %% [markdown]
# ## VS code 컨테이너 내부접속

# %% [markdown]
# vscode extension :
# - Container Tools
# - Dev Containers
# ---
# containers 아이콘 - containers - nginx 우클릭 - Attach visual studio code

# %% [markdown]
# ## nginx 테스트

# %% [markdown]
# - nginx 홈디렉터리: /usr/share/nginx/html
# - index.html 수정
# - 캐시무시 새로받음: ctrl + f5
#
# nginx 환경설정
# ---
# - cat /etc/nginx/conf.d/default.conf

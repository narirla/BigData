# %% [markdown]
# -------------------------
# 로그 확인하기
# -------------------------
# ```bash
# docker run nginx (로그를 콘솔에서 확인할수 있지만 다른작업 불가)
#
# docker run -d nginx
# docker ps
# docker logs 컨테이너아이디
#
#
# docker logs --tail 10 컨테이너아이디 # 마지막 10개 로그
#
# docker run -d -p 80:80 nginx
#
# docker logs -f 컨테이너아이디 # 실시간 생성로그
# localhost 접속후 실시간 로그 확인

# %% [markdown]
# **0** 의 의미는 **"명령어를 입력한 시점 이전의 과거 로그는 하나도 출력하지 마라"** 는 뜻.
# **"과거 기록은 무시하고, 지금 이 순간부터 발생하는 실시간 로그만 보겠다"** 는 설정
# ```bash
# docker logs --tail 0 -f 9c

# %% [markdown]
# ## 🔟 리눅스에서 자주 쓰는 커맨드 TOP 10
#
# | # | 명령어 | 용도 | 기본 사용법 | 실전 예시 |
# |---|---|---|---|---|
# | 1 | `ls` | 파일·폴더 목록 보기 | `ls [옵션]` | `ls -la` (숨김 포함 자세히) |
# | 2 | `cd` | 디렉토리 이동 | `cd 경로` | `cd /storage/emulated/0` |
# | 3 | `pwd` | 현재 위치 확인 | `pwd` | 현재 작업 경로 확인 |
# | 4 | `mkdir` | 폴더 생성 | `mkdir 이름` | `mkdir project` |
# | 5 | `rm` | 파일/폴더 삭제 | `rm [옵션] 대상` | `rm -rf cache/` |
# | 6 | `cp` | 파일/폴더 복사 | `cp 원본 대상` | `cp a.txt b.txt` |
# | 7 | `mv` | 이동 / 이름 변경 | `mv 원본 대상` | `mv old.py new.py` |
# | 8 | `cat` | 파일 내용 출력 | `cat 파일` | `cat README.md` |
# | 9 | `grep` | 문자열 검색 | `grep 패턴 파일` | `grep "error" log.txt` |
# |10 | `chmod` | 권한 변경 | `chmod 권한 파일` | `chmod +x run.sh` |

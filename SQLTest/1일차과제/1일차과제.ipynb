# %%
import pymysql

try:
    db  = pymysql.connect(host="127.0.0.1", user='root', password='1234' , database='test')
    cur = db.cursor()
    sql = "insert into product values(pname,quantity,pdate)"
    cur.execute(sql)
    db.commit()
    db.close()
    print("추가성공")
except Exception as err:
    print('에러',err)
# Out:
# 추가성공

# %%
import numpy as np

# %%
arr = np.array([11,22,33,44,55])
arr
# Out:
# array([11, 22, 33, 44, 55])

# %% [markdown]
# ## 인덱싱
# - 0,1,2,3,....
# - ...,-3,-2,-1

# %%
arr[0]
# Out:
# np.int64(11)

# %%
arr[-1]
# Out:
# np.int64(55)

# %% [markdown]
# ### 복수개 인덱싱
# [[인덱스번호,...]]

# %%
arr[[1,4]] #1인덱스. 4인덱스 추출
# Out:
# array([22, 55])

# %%
arr
# Out:
# array([11, 22, 33, 44, 55])

# %%
arr[[-1,-3]]
# arr[[4,2]]
# Out:
# array([55, 33])

# %% [markdown]
# ### boolean indexing
# - 데이터의 갯수 만큼 나열해 준다.
# -[[True,False,...]]
# #데이터 필터링에 유용

# %%
arr[[True,False,False,True,True]] #True 값만 출력
# Out:
# array([11, 44, 55])

# %%
arr
# Out:
# array([11, 22, 33, 44, 55])

# %% [markdown]
# ## 슬라이싱
# - [시작인덱스:끝인덱스:증가치]
# - 시작인덱스 <= index < 끝인덱스

# %%
arr[1:4:1]
# Out:
# array([22, 33, 44])

# %%
arr
# Out:
# array([11, 22, 33, 44, 55])

# %%
arr[1:4:2] #1,3
# Out:
# array([22, 44])

# %%
arr[1:4]
# Out:
# array([22, 33, 44])

# %%
arr[:4]
# Out:
# array([11, 22, 33, 44])

# %%
arr[:-1] #0<=idx<-1
# Out:
# array([11, 22, 33, 44])

# %%
arr[::-1] #-1,-2,...
# Out:
# array([55, 44, 33, 22, 11])

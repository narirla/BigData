# %%
class Test:
    def __init__(self): ## 생성자 함수
        print('init call')
        self.a = 0 # 간접연산자: 
        self.b = 0

    def setData(self, x,y): # 멤버 함수
        self.a = x
        self.b = y

    def show(self): # 멤버함수
        print(self.a, self.b)

obj = Test() #Test 객체(Test 클래스의 멤버 데이터 메모리할당 완료), 레퍼런스, 변수
# obj.__init__(obj) # <-- 컴파일러가 추가
obj.setData(10,20) # obj.setData(obj, 10,20)
obj.show() # obj.show(obj)
print( obj.a , obj.b)
# Out:
# init call
# 10 20
# 10 20

# %%
class Test:
    def __init__(self): 
        print('init self', id(self))
        self.a = 0 
        self.b = 0

    def setData(self, x,y): 
        print('setData self', id(self))
        self.a = x
        self.b = y

    def show(self): 
        print('show self', id(self))
        print(self.a, self.b)

obj = Test() 
print( 'obj주소', id(obj))
# obj.__init__(obj) # <-- 컴파일러가 추가
obj.setData(10,20) # obj.setData(obj, 10,20)
obj.show() # obj.show(obj)
print( obj.a , obj.b)

print("============================")

obj1 = Test()
print( 'obj1주소', id(obj1))
# obj1.__init__(obj1) # <-- 컴파일러가 추가
obj1.setData(11,22) # obj.setData(obj1, 11,22)
obj1.show() # obj1.show(obj1)
print(obj1.a, obj1.b)
# Out:
# init self 1708584566016
# obj주소 1708584566016
# setData self 1708584566016
# show self 1708584566016
# 10 20
# 10 20
# ...
# init self 1708584565008
# obj1주소 1708584565008
# setData self 1708584565008
# show self 1708584565008
# 11 22
# 11 22

# %% [markdown]
# #### 정리
# - 동일한 클래스에서 여러개의 객체가 발생한 경우 멤버 데이터는 별도로 할당됨
# (멤버함수 코드로 공유)
# - 멤버함수 호출시 어떻게 각각의 객체의 영역데에터에 대해 read/write가 가능한가?
# 정답 -> self가 있기 때문

# %%
a = int(10)
a = 10

# %%
mylist = list([10,20,30])
mylist = [10,20,30]

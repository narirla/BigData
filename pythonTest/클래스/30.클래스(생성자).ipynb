# %%
class Test:
    st = 100 #static 멤버(객체 생성 X), 클래스 변수
    def __init__(self): 
        self.a = 0 # instance변수 (반드시 객체 생성필요)
        self.b = 0 # instance변수 (반드시 객체 생성필요)

    def setData(self, x,y): 
        self.a = x
        self.b = y

    def show(self): 
        print(self.a, self.b)

print( Test.st)
obj = Test()
# Out:
# 100

# %%
class Test:
    def __init__(self,a,b): 
        self.a = a  
        self.b = b

    def setData(self, x,y): 
        self.a = x
        self.b = y

    def show(self): 
        print(self.a, self.b)

obj = Test( 10, 20)
obj.show()
obj.setData(100,200)
obj.show()
# Out:
# 10 20
# 100 200

# %%
class Test:
    def __init__(self,a=0,b=0): 
        self.a = a  
        self.b = b

    def setData(self, x,y): 
        self.a = x
        self.b = y

    def show(self): 
        print(self.a, self.b)

# obj = Test( 10,20)
# obj._init__(obj,10,20)
# obj = Test( )
# obj._init__(obj,10,20)
obj = Test( b= 100)
obj.show()
obj.setData(100,200)
obj.show()
# Out:
# 0 100
# 100 200

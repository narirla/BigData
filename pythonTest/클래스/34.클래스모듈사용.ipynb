# %%
import mclass as m

std1 = m.Student('김철수',40,'부산시')
std1.show()

rst = m.hap(10,20)
print(rst)

print(m.Circle.circle_area(10))

print(myg)
# Out:
# 이름 김철수
# 나이 40
# 주소 부산시
# 30
# 314.0
# 100

# %%
from mclass import Student, hap, Circle, myg
std1 = m.Student('김철수',40,'부산시')
std1.show()

rst = m.hap(10,20)
print(rst)

print(m.Circle.circle_area(10))

print(myg)
# Out:
# 이름 김철수
# 나이 40
# 주소 부산시
# 30
# 314.0
# 100

# %% [markdown]
# ## 🧙‍♂️ 20 Most Common Magic Methods in Python OOP
#
# | Magic Method | Syntax | Usage / Description |
# |:-------------:|:--------|:--------------------|
# | `__new__` | `__new__(cls, *args, **kwargs)` | Invoked **before `__init__`** to allocate memory to object |
# | `__init__` | `__init__(self, *args, **kwargs)` | Invoked **after `__new__`** to initialize the object |
# | `__repr__` | `__repr__(self)` | Invoked when `str(obj)` or `print(obj)` is called |
# | `__int__` | `__int__(self)` | Invoked when `int(obj)` is used |
# | `__len__` | `__len__(self)` | Invoked when `len(obj)` is used |
# | `__call__` | `__call__(self, *args, **kwargs)` | Invoked when class object is called as a function: `obj()` |
# | `__getitem__` | `__getitem__(self, key)` | Invoked when object is indexed: `obj[key]` |
# | `__setitem__` | `__setitem__(self, key, value)` | Invoked when indexed value is set: `obj[key] = value` |
# | `__delitem__` | `__delitem__(self, key)` | Invoked when an item is deleted: `del obj[key]` |
# | `__contains__` | `__contains__(self, item)` | Invoked when `in` operator is used: `item in obj` |
# | `__bool__` | `__bool__(self)` | Invoked when object is used in a boolean context: `if obj` or `bool(obj)` |
# | `__iter__` | `__iter__(self)` | Invoked when object is iterated: `for x in obj` |
# | `__eq__` | `__eq__(self, other)` | Invoked when `==` operator is used to compare two objects |
# | `__ne__` | `__ne__(self, other)` | Invoked when `!=` operator is used |
# | `__gt__` | `__gt__(self, other)` | Invoked when `>` operator is used |
# | `__add__` | `__add__(self, other)` | Invoked when `+` operator is used |
# | `__mul__` | `__mul__(self, other)` | Invoked when `*` operator is used |
# | `__abs__` | `__abs__(self)` | Invoked when `abs(obj)` is used |
# | `__neg__` | `__neg__(self)` | Invoked when unary minus `-obj` is used |
# | `__invert__` | `__invert__(self)` | Invoked when bitwise NOT `~obj` is used |
#
# ---

# %% [markdown]
# ## 🧙‍♀️ 파이썬 매직 메서드 (Magic Methods, Dunder Methods) 정리
#
# | 구분 | 매직 메서드 | 문법(Syntax) | 설명(Description) |
# |:-----:|:-------------|:--------------|:------------------|
# | **객체 생성/초기화** | `__new__` | `__new__(cls, *args, **kwargs)` | 인스턴스가 생성되기 **전에 호출**, 메모리 할당을 담당 |
# |  | `__init__` | `__init__(self, *args, **kwargs)` | 인스턴스가 생성된 **후 호출**, 초기화 작업 수행 |
# |  | `__del__` | `__del__(self)` | 객체가 **소멸될 때 호출**, 리소스 정리용 |
# | **문자열 / 형변환** | `__str__` | `__str__(self)` | `print()` 또는 `str()`로 문자열 표현 요청 시 호출 |
# |  | `__repr__` | `__repr__(self)` | 객체의 **공식 표현** 반환 (디버깅용) |
# |  | `__format__` | `__format__(self, format_spec)` | `format()`이나 f-string 형식 지정 시 호출 |
# |  | `__bytes__` | `__bytes__(self)` | `bytes()` 변환 시 호출 |
# |  | `__int__` | `__int__(self)` | `int(obj)` 호출 시 실행 |
# |  | `__float__` | `__float__(self)` | `float(obj)` 호출 시 실행 |
# |  | `__bool__` | `__bool__(self)` | `bool(obj)` 또는 `if obj:` 문에서 평가될 때 호출 |
# | **컨테이너 관련** | `__len__` | `__len__(self)` | `len(obj)` 호출 시 길이 반환 |
# |  | `__getitem__` | `__getitem__(self, key)` | `obj[key]` 접근 시 호출 |
# |  | `__setitem__` | `__setitem__(self, key, value)` | `obj[key] = value` 시 호출 |
# |  | `__delitem__` | `__delitem__(self, key)` | `del obj[key]` 시 호출 |
# |  | `__contains__` | `__contains__(self, item)` | `item in obj` 호출 시 실행 |
# |  | `__iter__` | `__iter__(self)` | `for x in obj:` 반복 시 호출 |
# |  | `__next__` | `__next__(self)` | 반복자에서 다음 요소를 반환할 때 호출 |
# | **호출 / 비교 / 논리** | `__call__` | `__call__(self, *args, **kwargs)` | 객체를 함수처럼 호출할 때 실행 |
# |  | `__eq__` | `__eq__(self, other)` | `==` 비교 시 호출 |
# |  | `__ne__` | `__ne__(self, other)` | `!=` 비교 시 호출 |
# |  | `__lt__` | `__lt__(self, other)` | `<` 비교 시 호출 |
# |  | `__le__` | `__le__(self, other)` | `<=` 비교 시 호출 |
# |  | `__gt__` | `__gt__(self, other)` | `>` 비교 시 호출 |
# |  | `__ge__` | `__ge__(self, other)` | `>=` 비교 시 호출 |
# | **산술 연산자 오버로딩** | `__add__` | `__add__(self, other)` | `+` 덧셈 연산 시 호출 |
# |  | `__sub__` | `__sub__(self, other)` | `-` 뺄셈 연산 시 호출 |
# |  | `__mul__` | `__mul__(self, other)` | `*` 곱셈 연산 시 호출 |
# |  | `__matmul__` | `__matmul__(self, other)` | `@` 행렬 곱 연산 시 호출 |
# |  | `__truediv__` | `__truediv__(self, other)` | `/` 나눗셈 시 호출 |
# |  | `__floordiv__` | `__floordiv__(self, other)` | `//` 정수 나눗셈 시 호출 |
# |  | `__mod__` | `__mod__(self, other)` | `%` 나머지 연산 시 호출 |
# |  | `__pow__` | `__pow__(self, other)` | `**` 거듭제곱 시 호출 |
# | **역연산자 (오른쪽 피연산자)** | `__radd__` | `__radd__(self, other)` | `other + obj` 처럼 오른쪽 피연산자로 사용될 때 호출 |
# |  | `__rsub__` | `__rsub__(self, other)` | `other - obj` |
# |  | `__rmul__` | `__rmul__(self, other)` | `other * obj` |
# |  | `__rtruediv__` | `__rtruediv__(self, other)` | `other / obj` |
# |  | `__rfloordiv__` | `__rfloordiv__(self, other)` | `other // obj` |
# |  | `__rmod__` | `__rmod__(self, other)` | `other % obj` |
# |  | `__rpow__` | `__rpow__(self, other)` | `other ** obj` |
# | **단항 연산자** | `__neg__` | `__neg__(self)` | 단항 음수 연산자 `-obj` |
# |  | `__pos__` | `__pos__(self)` | 단항 양수 연산자 `+obj` |
# |  | `__abs__` | `__abs__(self)` | `abs(obj)` 호출 시 |
# |  | `__invert__` | `__invert__(self)` | 비트 반전 `~obj` |
# | **비트 연산자** | `__and__` | `__and__(self, other)` | 비트 AND `&` |
# |  | `__or__` | `__or__(self, other)` | 비트 OR `\|` |
# |  | `__xor__` | `__xor__(self, other)` | 비트 XOR `^` |
# |  | `__lshift__` | `__lshift__(self, other)` | 비트 왼쪽 시프트 `<<` |
# |  | `__rshift__` | `__rshift__(self, other)` | 비트 오른쪽 시프트 `>>` |
# | **속성 접근 / 제어** | `__getattr__` | `__getattr__(self, name)` | 존재하지 않는 속성 접근 시 호출 |
# |  | `__getattribute__` | `__getattribute__(self, name)` | **모든 속성 접근 시** 호출 (주의: 무한 재귀 가능) |
# |  | `__setattr__` | `__setattr__(self, name, value)` | 속성 설정 시 호출 |
# |  | `__delattr__` | `__delattr__(self, name)` | 속성 삭제 시 호출 |
# | **컨텍스트 매니저** | `__enter__` | `__enter__(self)` | `with` 블록 진입 시 호출 |
# |  | `__exit__` | `__exit__(self, exc_type, exc_value, traceback)` | `with` 블록 종료 시 호출 |
# | **객체 표현 및 기타** | `__hash__` | `__hash__(self)` | 객체의 해시값 반환 (`set`, `dict` 키로 사용 가능) |
# |  | `__copy__`, `__deepcopy__` | `__copy__(self)` / `__deepcopy__(self, memo)` | 얕은 복사 및 깊은 복사 수행 시 호출 |
# |  | `__slots__` | 클래스 변수로 선언 | 인스턴스의 속성 제한 및 메모리 절약 |
#
# ---
#
# > 💡 **참고:**
# > - 매직 메서드는 모두 `__이름__` 형태로 되어 있으며, 파이썬 내부 동작을 **사용자 정의 객체가 제어**할 수 있게 해줍니다.
# > - 특히 연산자 오버로딩(`+`, `-`, `*`, `/`, 비교 등)을 통해 **자연스러운 수학적 표현**을 구현할 수 있습니다.

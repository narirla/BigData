# %% [markdown]
# ### 멤버 데이터를 직접 접근하지 않고
# ### 멤버데이터 R/W
# ### 데이터 무결성을 보존

# %%
class Calender:
    def __init__(self):
        self.month = 0

    def setMonth(self, month):
        if month <1 or month>12:
            print('잘못된 개월')
        else:
            self.month = month

    def getMonth(self):
        return self.month
    
cal = Calender()
# cal.month = 13
# cal.setMonth(13) #cal.setMonth(cal,13)
cal.setMonth(12)
print(cal.getMonth())
# Out:
# 12

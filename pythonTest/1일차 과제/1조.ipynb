# %% [markdown]
# ## 문제 1

# %%
print('신씨가 소리질렀다. "도둑이야".')
# Out:
# 신씨가 소리질렀다. "도둑이야".

# %% [markdown]
# ## 문제 2

# %%
d = {'시가총액':'298조', '현재가':'50,000원','PER':15.79}
d
# Out:
# {'시가총액': '298조', '현재가': '50,000원', 'PER': 15.79}

# %% [markdown]
# ## 문제 3

# %%
license_plate = "24 가 2210"
print(license_plate[-4:])
# Out:
# 2210

# %% [markdown]
# ## 문제 4

# %%
string = "홀짝홀짝홀짝"
print(string[::2])
# Out:
# 홀홀홀

# %% [markdown]
# ## 문제 5

# %%
phone_number = "010-1111-2222"
print(phone_number.replace('-', ' '))
# Out:
# 010 1111 2222

# %% [markdown]
# ## 문제 6

# %%
url = "http://sharebook.kr"
print(url[-2:])
print(url.split('.')[-1])
# Out:
# kr
# kr

# %% [markdown]
# ## 문제 7

# %%
ticker = "btc_krw"
print(ticker.upper())
# Out:
# BTC_KRW

# %% [markdown]
# ## 문제 8

# %%
movie_rank = ['닥터 스트레인지', '스플릿', '럭키', '배트맨']
movie_rank.insert(1,'슈퍼맨')
print(movie_rank)
# Out:
# ['닥터 스트레인지', '슈퍼맨', '스플릿', '럭키', '배트맨']

# %% [markdown]
# ## 문제 9

# %%
price = ['20180728', 100, 130, 140, 150, 160, 170]
print(price[1::])
# Out:
# [100, 130, 140, 150, 160, 170]

# %% [markdown]
# ## 문제 10

# %%
interest = ['삼성전자', 'LG전자', 'Naver', 'SK 하이닉스', '미래에셋대우']
a,b,c,d,e = interest
print(a,b,c,d,e)
# Out:
# 삼성전자 LG전자 Naver SK 하이닉스 미래에셋대우

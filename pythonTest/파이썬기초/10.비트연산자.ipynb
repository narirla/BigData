# %%
a = 3
rst = a & 1
print(rst)
# Out:
# 1

# %% [markdown]
# 비트 and(&) 모두 1인 경우 하나라도 0이면 0
#   00000011
# & 00000001
# ==========
#          1

# %%
a = 3
rst = a | 1
print(rst)
# Out:
# 3

# %% [markdown]
# 비트 or(|) 모두 0인 경우 하나라도 1이면 1
#   00000011
# & 00000001
# ==========
#         11

# %%
a = 3
rst = a << 1
print(rst)
# Out:
# 6

# %% [markdown]
# 00000011
# <<이동수
# 00000110

# %%
a = 3
rst = a >> 1
print(rst)
# Out:
# 1

# %% [markdown]
# 00000011
# >>이동수
# 0000001

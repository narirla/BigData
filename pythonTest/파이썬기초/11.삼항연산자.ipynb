# %% [markdown]
# True인 경우 if 관계 또는 논리 else False인 경우

# %%
a = -5
rst = 100 if a>0 else 200
print(rst)
# Out:
# 200

# %% [markdown]
# ### 퀴즈
# - 점수가 70점 이상이면 '합격' 아니며면 '불합격' 인 경우
# - 점수가 92점인 경우 합격 여부를 구하시오

# %%
a = 92
rst = '합격' if a>= 70 else '불합격'
print(rst)
# Out:
# 합격

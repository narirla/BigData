# %% [markdown]
# ### 인덱싱, 슬라이싱
# ### 복합데이터 타입에서의 특정 데이터 추출시 사용
# - 순서 있는 데이터 타입: 문자열, 리스트, 튜플
# - 순서 없는: 세트, 딕셔너리 (인덱싱, 슬라이딩 적용 X)

# %% [markdown]
# 인덱싱:[인덱스 번호]
# - 0,1,2,3,...
# - ...,-3,-2,-1

# %%
#      0  1  2  3  4
#     -5 -4 -3 -2 -1
my = [10,20,30,40,50]
print(my[0])
print(my[-5])
# Out:
# 10
# 10

# %%
my[3]
# Out:
# 40

# %%
t = (10,20,30)
print(t[0])
print(t[-1])
# Out:
# 10
# 30

# %%
s = 'abcde'
print(s[0])
print(s[-1])
# Out:
# a
# e

# %%
s = {10,20,30}
print(s[0]) #error

# %%
d = {'aa':10, 'bb':20, 'cc':30}
print(d['aa'])
# Out:
# 10

# %% [markdown]
# ### 슬라이싱
# - [시작인덱스:끝인덱스:증가치]
# - 시작인덱스 <=끝인덱스 < 증가치

# %%
my = [10,20,30,40,50] 
print(my[1:4:1]) #1<=인덱스<4 1,2,3
print(my[1:4:2]) #1<=인덱스<4 1,3
# Out:
# [20, 30, 40]
# [20, 40]

# %%
my[0:5:2] #0<=index<5 0,2,4
# Out:
# [10, 30, 50]

# %%
my[1:4] # 증가치 생략시 1증가가 기본 my[1:4:1]
# Out:
# [20, 30, 40]

# %%
my[:4] #시작인덱스 생력시 0 기본  my[0:4:1]
# Out:
# [10, 20, 30, 40]

# %%
my[1:] # 1<=index 1,2,3,4
# Out:
# [20, 30, 40, 50]

# %%
### 퀴즈: 마지막 데이터를 제외하고 리스트를 구하시오.
my[0:-1] # 0<= index < -1
# Out:
# [10, 20, 30, 40]

# %%
my[-3:] # -3<=index -3,-2,-1
# Out:
# [30, 40, 50]

# %%
my[-3::-1] #-3<= index -3,-4,-5
# Out:
# [30, 20, 10]

# %%
## 퀴즈 : 역리스트를 구하시오
my[-1::-1] #-1<= index -1,-2,-3,.....
# Out:
# [50, 40, 30, 20, 10]

# %%
my[::-1] #-1 증가치인 경우에 -1을 생략 가능
# Out:
# [50, 40, 30, 20, 10]

# %% [markdown]
# ##  퀴즈
# 50,30,10

# %%
my[-1::-2]
my[::-2]
# Out:
# [50, 30, 10]

# %%
my
# Out:
# [10, 20, 30, 40, 50]

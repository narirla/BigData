# %% [markdown]
# 문법: 산술연산자=
# - **=
# - *=
# - /=
# - %=
# - //=
# - +=
# - -=

# %%
a = 5
# a = a+2
a+=2
print(a)
# Out:
# 7

# %%
b = 5
# b = b**5
b**=2
print(b)
# Out:
# 25

# %%
c = 5
# c = c/2
c/=2
print(c)
# Out:
# 2.5

# %%
a = 1
# a = a+1
a+=1
# a++ X
print(a)
# Out:
# 2

# %%
print("hello")
# Out:
# hello

# %%
a = 10
b = 20
print(a)
print(b)
# Out:
# 10
# 20

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %% [markdown]
# # 테스트1
# ## 테스트2
# ### 테스트3
# #### 테스트4

# %% [markdown]
# ### 1. 정수 데이터 타입

# %%
a = 10
b = 1234567891235
print(a) 
print(b) 
print(type(b))
# Out:
# 10
# 1234567891235
# <class 'int'>

# %% [markdown]
# #### 2. 실수타입

# %%
f = 3.14
print(f)
print(type(f))
# Out:
# 3.14
# <class 'float'>

# %%
f = 3.14
f1 = 3.141592e3
f2 = 3.141592e-3
print(f)
print(type(f))
print(f1)
print(type(f1))
print(f2)
print(type(f2))
# Out:
# 3.14
# <class 'float'>
# 3141.592
# <class 'float'>
# 0.003141592
# <class 'float'>

# %% [markdown]
# ### 3. bool

# %%
bb = True
cc = False
print(bb)
print(cc)
print(type(bb))
# Out:
# True
# False
# <class 'bool'>

# %%
# mymath 폴더 아래에 있는 danwi.py 함수 사용
import mymath.danwi

rst = mymath.danwi.cmToInch(10)
print(rst)
rst = mymath.danwi.mToMile(100)
print(rst)
# Out:
# 3.937
# 0.0621

# %%
import mymath.danwi as d
import mymath.circle as c

rst = d.cmToInch(10)
print(rst)
rst = d.mToMile(100)
print(rst)

rst = c.circle_area(5)
print(rst)
# Out:
# 3.937
# 0.0621
# 78.5

# %%
from mymath.danwi import cmToInch

rst = cmToInch(10)
print(rst)
# Out:
# 3.937

# %%
import sys 
sys.path #python path (import 라이브러리명을 인식할 수 있는 경로)
# Out:
# ['c:\\Python310\\python310.zip',
#  'c:\\Python310\\DLLs',
#  'c:\\Python310\\lib',
#  'c:\\Python310',
#  '',
#  'C:\\Users\\Dell3571\\AppData\\Roaming\\Python\\Python310\\site-packages',
#  'c:\\Python310\\lib\\site-packages']

# %% [markdown]
# ```text
# ### 라이브러리 종류
# 1. 내장함수 (print, input, int, list, tuple,.....): import 없이 사용
# 2. 표준함수 파이썬 제공 import 후 사용:
# 파이썬설치\lib
# import sys
# import os
# import match
# ...

# %%
# mylib.py에 있는 함수를 사용하겠다고 선언하는 호출부
import mylib 

rst = mylib.hap(10,20) #mylib 에 있는 hap함수 호출
print(rst)
rst = mylib.gop(10,20) #mylib 에 있는 gop함수 호출
print(rst)
# Out:
# 30
# 200

# %%
import mylib as m

rst = mylib.hap(10,20) #mylib 에 있는 hap함수 호출
print(rst)
rst = mylib.gop(10,20) #mylib 에 있는 gop함수 호출
print(rst)
# Out:
# 30
# 200

# %%
from mylib import hap,gop

rst = mylib.hap(10,20) #mylib 에 있는 hap함수 호출
print(rst)
rst = mylib.gop(10,20) #mylib 에 있는 gop함수 호출
print(rst)
# Out:
# 30
# 200

# %% [markdown]
# ### circle.py에 원과 관련된 함수를 모아둔 라이브러리를 만드시오 (원의 면적, 원기둥의 부피, 원뿔의 부피)
# 라이브러리를 import 해서 호출 후 결과를 보시오.

# %%
import circle as c

rst = c.circle_area(10)
print(rst)

rst = c.cylider(10,15)
print(rst)

rst = c.cone(10,15)
print(round(rst,2)) #round는 파이썬 내장함수
# Out:
# 314.0
# 4710.0
# 1570.0

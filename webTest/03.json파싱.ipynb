# %%
import json
fp = open('data/song.json')
data = json.load(fp) # 텍스트는 load
print(type(data))
data
# Out:
# <class 'dict'>
# {'kpop': {'slist': [{'album': 'album1',
#     'singer': 'singer1',
#     'title': 'title1'},
#    {'album': 'album2', 'singer': 'singer2', 'title': 'title2'},
#    {'album': 'album3', 'singer': 'singer3', 'title': 'title3'}]}}

# %%
data['kpop']['slist']
# Out:
# [{'album': 'album1', 'singer': 'singer1', 'title': 'title1'},
#  {'album': 'album2', 'singer': 'singer2', 'title': 'title2'},
#  {'album': 'album3', 'singer': 'singer3', 'title': 'title3'}]

# %%
for d in data['kpop']['slist']:
    print(d['album'])
    print(d['singer'])
    print(d['title'])
    print('----------------------')
# Out:
# album1
# singer1
# title1
# ----------------------
# album2
# singer2
# title2
# ----------------------
# album3
# singer3
# title3
# ----------------------

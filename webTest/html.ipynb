# %% [markdown]
# 태그종류(엘리먼트)
#
# 1. block 요소
# - 개행발생 : hn, p , ul, ol
# - 개행발생 X : li, tr, table
# 2. inline 요소 (컨텐츠 크기로 브라우저의 영역을 점유)
# - span, img, input , td, th, a, label, button

# %% [markdown]
# <table>
#     <thead>
#         <tr><th>이름</th><th>나이</th><th>생일</th></tr>
#     </thead>
#     <tbody>
#         <tr><td>홍길동</td><td>20</td><td>2001-11-12</td></tr>
#         <tr><td>이순신</td><td>30</td><td>1991-10-12</td></tr>
#     </tbody>
# </table>

# %% [markdown]
# ### 이전 selenium 버전

# %% [markdown]
# ### 주요 메소드
# ```python
#
# - driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[1]/div/div[3]/form/fieldset/button/span[2]')
# xpath 로 접근
#
# - driver.find_element_by_class_name('ico_search_submit')
#
# class 속성으로 접근
#
# - driver.find_element_by_id('ke_kbd_btn')
#
# id 속성으로 접근
#
# - driver.find_element_by_link_text('회원가입')
#
# 링크가 달려 있는 텍스트로 접근
#
# - driver.find_element_by_css_selector('#account > div > a')
#
# css 셀렉터로 접근
#
# - driver.find_element_by_name('join')
#
# name 속성으로 접근
#
# - driver.find_element_by_partial_link_text('가입')
#
# 링크가 달려 있는 엘레먼트에 텍스트 일부만 적어서 해당 엘레먼트에 접근
#
# - driver.find_element_by_tag_name('input')
#
# 태그 이름으로 접근
#
# - driver.find_element_by_tag_name('input').find_element_by_tag_name('a')
#
# input 태그 하위태그인 a 태그에 접근
#
# - driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[1]/div/div[3]/form/fieldset/button/span[2]').find_element_by_name('join')
#
# xpath 로 접근한 엘레먼트의 안에 join 이라는 속성을 가진 tag 엘레먼트에 접근

# %% [markdown]
# ## 현재 selenium 버전: find_element(By.XPATH, By.ID, By.LINK_TEXT,...... )

# %%
# from selenium.webdriver.common.by import By

# driver.find_element(By.XPATH, '//button[text()="Some text"]') 
# driver.find_element(By.XPATH, '//button') 
# driver.find_element(By.ID, 'loginForm') 
# driver.find_element(By.LINK_TEXT, 'Continue') 
# driver.find_element(By.PARTIAL_LINK_TEXT, 'Conti') 
# driver.find_element(By.NAME, 'username') 
# driver.find_element(By.TAG_NAME, 'h1') 
# driver.find_element(By.CLASS_NAME, 'content') 
# driver.find_element(By.CSS_SELECTOR, 'p.content')

# driver.find_elements(By.ID, 'loginForm') 
# driver.find_elements(By.CLASS_NAME, 'content')

# %%
# %pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install webdriver-manager
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

def set_chrome_driver():
    chrome_options = webdriver.ChromeOptions()
    # chrome_options.add_argument('headless') #<- 단독 실행히 웹 페이지가 실행이 안됨
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), 
                              options=chrome_options)
    return driver

# %%
driver = set_chrome_driver()

# %%
murl = 'https://www.menupan.com/restaurant/bestrest/bestrest.asp?pt=rt&areacode=bs205'
driver.get(murl)

# %%
driver.current_url
# Out:
# 'https://www.menupan.com/restaurant/bestrest/bestrest.asp?pt=rt&areacode=bs205'

# %%
aList = driver.find_elements(By.CSS_SELECTOR, '.restName > a')
for a in aList:
    print(a.get_attribute('outerHTML'))
    print(a.text)
    print('====================================')
# Out:
# <a href="/restaurant/onepage.asp?acode=H602082" target="_blank">부산돼지국밥</a>
# 부산돼지국밥
# ...
# <a href="/restaurant/onepage.asp?acode=B600008" target="_blank">호찐빵</a>
# 호찐빵
# ...
# <a href="/restaurant/onepage.asp?acode=J600539" target="_blank">히노아지 센텀점</a>
# 히노아지 센텀점
# ...
# <a href="/restaurant/onepage.asp?acode=B600043" target="_blank">상국이네</a>
# 상국이네
# ...
# <a href="/restaurant/onepage.asp?acode=D600801" target="_blank">카페윤</a>
# 카페윤
# ...
# <a href="/restaurant/onepage.asp?acode=G600035" target="_blank">옵스 마린시티점</a>
# 옵스 마린시티점
# ...
# <a href="/restaurant/onepage.asp?acode=H600631" target="_blank">기장곰장어</a>
# 기장곰장어
# ...
# <a href="/restaurant/onepage.asp?acode=H601524" target="_blank">오반장</a>
# 오반장
# ...
# <a href="/restaurant/onepage.asp?acode=H601497" target="_blank">뜰아래채</a>
# 뜰아래채
# ...
# <a href="/restaurant/onepage.asp?acode=H601506" target="_blank">일번지 자갈치 산곰장어</a>
# 일번지 자갈치 산곰장어
# ...
# <a href="/restaurant/onepage.asp?acode=H601665" target="_blank">춘하추동밀면 해운대점</a>
# 춘하추동밀면 해운대점
# ...

# %%
# driver.find_elements(By.CSS_SELECTOR, '.listType')
listTypes = driver.find_elements(By.CLASS_NAME, 'listType')
for t in listTypes:
    print(t.text)
# Out:
# 한식
# 분식
# 일식
# 분식
# 카페/주점
# 베이커리
# 한식
# 한식
# 한식
# 한식
# 한식
# 카페/주점
# 한식
# 카페/주점
# 한식
# 기타/세계
# 한식
# 한식
# 한식
# 뷔페
# 한식
# 일식
# 중식
# 한식
# 한식

# %%
driver.page_source #현재 열려있는 페이지에 대한 속성을 가져옴
# Out:
# '<html xmlns="http://www.w3.org/1999/xhtml"><head>\n\t<title>맛집TOP1000 - 매일매일 맛있게 메뉴판닷컴</title>\n\t<meta http-equiv="Content-Type" content="text/html; charset=euc-kr">\n\t<link rel="stylesheet" href="/common/css/default.css" type="text/css">\n\t<link rel="stylesheet" href="/common/style/restaurant/bestrest.css" type="text/css">\n\t<script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-VMG01E0N1E&amp;cx=c&amp;_slc=1"></script><script async="" src="//www.google-analytics.com/analytics.js"></script><script language="javascript" src="/script/jquery/jquery-latest.min.js"></script>\n\t<script language="javascript">\n\t<!--\n\t\t//-- hide all layer\n\t\tfunction fn_close_all_layer() {\n\t\t\tfn_disp_layer_standard(\'hide\');\n\t\t\tfn_disp_layer_type(\'hide\');\n\t\t}\n\t\t//-- show information\n\t\tfunction fn_disp_layer_standard(p_cmd) {\n\t\t\tif (p_cmd == \'show\') {\n\t\t\t\tfn_close_all_layer();\n\t\t\t\t$(\'#id_lyr_standard\').show();\n\t\t\t}\n\t\
# ...

# %%
from bs4 import BeautifulSoup

# %%
html = BeautifulSoup(driver.page_source, 'html.parser')
html
# Out:
# <html xmlns="http://www.w3.org/1999/xhtml"><head>
# <title>맛집TOP1000 - 매일매일 맛있게 메뉴판닷컴</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="/common/css/default.css" rel="stylesheet" type="text/css"/>
# <link href="/common/style/restaurant/bestrest.css" rel="stylesheet" type="text/css"/>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-VMG01E0N1E&amp;cx=c&amp;_slc=1" type="text/javascript"></script><script async="" src="//www.google-analytics.com/analytics.js"></script><script language="javascript" src="/script/jquery/jquery-latest.min.js"></script>
# <script language="javascript">
# 	<!--
# 		//-- hide all layer
# 		function fn_close_all_layer() {
# 			fn_disp_layer_standard('hide');
# 			fn_disp_layer_type('hide');
# 		}
# 		//-- show information
# 		function fn_disp_layer_standard(p_cmd) {
# 			if (p_cmd == 'show') {
# 				fn_close_all_layer();
# 				$('#id_lyr_standard').show();
# 			}
# 			else if (p_cmd == 'hide') {
# ...

# %%
aList = html.select('.restName > a')
for a in aList:
    print(a)
    print(a.text)
    print('----------------------------------')
# Out:
# <a href="/restaurant/onepage.asp?acode=H602082" target="_blank">부산돼지국밥</a>
# 부산돼지국밥
# ----------------------------------
# <a href="/restaurant/onepage.asp?acode=B600008" target="_blank">호찐빵</a>
# 호찐빵
# ----------------------------------
# <a href="/restaurant/onepage.asp?acode=J600539" target="_blank">히노아지 센텀점</a>
# 히노아지 센텀점
# ----------------------------------
# <a href="/restaurant/onepage.asp?acode=B600043" target="_blank">상국이네</a>
# 상국이네
# ----------------------------------
# <a href="/restaurant/onepage.asp?acode=D600801" target="_blank">카페윤</a>
# 카페윤
# ----------------------------------
# <a href="/restaurant/onepage.asp?acode=G600035" target="_blank">옵스 마린시티점</a>
# 옵스 마린시티점
# ----------------------------------
# <a href="/restaurant/onepage.asp?acode=H600631" target="_blank">기장곰장어</a>
# 기장곰장어
# ----------------------------------
# <a href="/restaurant/onepage.asp?acode=H601524" target="_blank">오반장</a>
# 오반장
# ----------------------------------
# ...

# %%
murl = 'https://www.menupan.com/'
driver.get(murl)

# %%
#search_window[type='text']
mysel = '#defaultHeader > form:nth-child(2) > div > div > fieldset > div > input[type=text]'
# myinput = driver.find_element(By.CSS_SELECTOR, ".search_window [type= 'text']")
myinput = driver.find_element(By.CSS_SELECTOR, mysel)
myinput.send_keys('중식')

# %%
mybtn = driver.find_element(By.CSS_SELECTOR, '.search_btn')
mybtn.click()

# %%
# driver.find_element(By.CSS_SELECTOR, ".search_window [type= 'text']").send_keys(중식)
# driver.find_element(By.CSS_SELECTOR, '.search_btn').click()

# %%
### 퀴즈
driver.find_element(By.CSS_SELECTOR, '.gnb_menu01 > a').click()

# %%
driver.find_element(By.CSS_SELECTOR, "[name = 'MemberId']").send_keys('test')
driver.find_element(By.CSS_SELECTOR, "[name = 'MemberPw']").send_keys('test1')
driver.find_element(By.CSS_SELECTOR, "[src='/img/btn_login.gif']" ).click()

# %% [markdown]
# ### 네이버 쇼핑몰

# %%
nurl = 'https://shopping.naver.com/ns/home'
driver.get(nurl)

# %%
driver.find_element(By.CSS_SELECTOR, '#input_text').send_keys('모니터')

# %%
murl = 'https://www.musinsa.com/main/musinsa/recommend?skip_bf=Y&gf=A&utm_source=naver_brandsearch&utm_medium=da&utm_campaign=mujinjangwinter_PC_CPC_NEWBRCP1602&utm_content=mujinjang&utm_term=CR&source=NEWBRCP1602'
driver.get(murl)

# %%
s = '#commonSearchHome > div > main > header > div > input'
driver.find_element(By.CSS_SELECTOR, s ).send_keys('패딩')

# %%
s= '#commonSearchHome > div > main > header > div > button.inline-flex.items-center.justify-center.group-data-\[disabled\]\:cursor-not-allowed.focus\:outline-none.size-5.sc-97s1c6-9.bqUeBc.search-home-search-bar-icon-search.gtm-click-button'
driver.find_element(By.CSS_SELECTOR, s ).click()

# %%
driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')

# %%
murl = 'https://www.menupan.com/restaurant/bestrest/bestrest.asp?pt=rt&areacode=bs205'
driver.get(murl)

# %%
s = 'body > div > div.container > div.bestRest > div.ranking > div.paging > a:nth-child(4)'
driver.find_element(By.CSS_SELECTOR, s ).click()

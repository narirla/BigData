# %%
import numpy as np

# %%
def softmax(z):
    e= np.exp(z)
    print(e)
    print('='*10)
    print(e/e.sum())

# %%
z =np.array( [2.0, 1.0, 0.1] )
softmax(z)
# Out:
# [7.3890561  2.71828183 1.10517092]
# ...
# [0.65900114 0.24243297 0.09856589]

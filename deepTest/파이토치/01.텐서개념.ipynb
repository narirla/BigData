# %%
pip install torch torchvision
# Out:
# Requirement already satisfied: torch in c:\python310\lib\site-packages (2.9.1)
# Requirement already satisfied: torchvision in c:\python310\lib\site-packages (0.24.1)
# Requirement already satisfied: jinja2 in c:\python310\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\python310\lib\site-packages (from torch) (2025.12.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\python310\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\python310\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\python310\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: filelock in c:\python310\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: numpy in c:\python310\lib\site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\python310\lib\site-packages (from torchvision) (12.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\python310\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python310\lib\site-packages (from jinja2->torch) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch

# %%
torch.__version__
# Out:
# '2.9.1+cpu'

# %%
t1 = torch.tensor( [1,2,3,4,5], dtype=torch.float32)
t1
# Out:
# tensor([1., 2., 3., 4., 5.])

# %%
# 미분을 통해 수정되는 텐서노드
t2 = torch.tensor( 2.0, dtype=torch.float32, requires_grad=True)
t2
# Out:
# tensor(2., requires_grad=True)

# %%
t3 = torch.FloatTensor( [1,2,3,4,5] )

# %%
t4 = torch.IntTensor( [1,2,3,4,5] )

# %%
t4.numpy()
# Out:
# array([1, 2, 3, 4, 5], dtype=int32)

# %%
t5 = torch.tensor( 10 ) # scalar 노드면 item()
t5.item()
# Out:
# 10

# %%
## 연산
a = torch.tensor( 5 )
b = torch.tensor( [1,2,3])

# %%
type( a )
# Out:
# torch.Tensor

# %%
c = torch.add( a,b ) # [5,5,5] + [1,2,3]
c
# Out:
# tensor([6, 7, 8])

# %%
d = a.add( b )
d
# Out:
# tensor([6, 7, 8])

# %%
e = a+b
e
# Out:
# tensor([6, 7, 8])

# %% [markdown]
# ## 인덱싱 슬라이싱

# %%
t = torch.tensor( [11,22,33,44,55])
t
# Out:
# tensor([11, 22, 33, 44, 55])

# %%
t[0].item()
# Out:
# 11

# %%
t[-1]
# Out:
# tensor(55)

# %%
t[1:3].numpy()
# Out:
# array([22, 33])

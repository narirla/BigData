# %% [markdown]
# ## 1. Cost Function (비용 함수) 정의
#
# **최소 제곱 오차(Mean Squared Error, MSE)**를 기반으로 한 비용 함수의 정의입니다.
#
# $$
# \text{cost}(W) = \frac{1}{m}\sum_{i=1}^{m} (Wx^{(i)} - y^{(i)})^2
# $$
#
# $\Downarrow$
#
# 경사 하강법의 미분 계산을 용이하게 하기 위해 $\frac{1}{2}$을 추가하여 재정의합니다.
#
# $$
# \text{cost}(W) = \frac{1}{2m}\sum_{i=1}^{m} (Wx^{(i)} - y^{(i)})^2
# $$
#
# ---
#
# ## 2. Gradient Descent (경사 하강법)
#
# 비용 함수 $\text{cost}(W)$를 최소화하기 위해 가중치 $W$를 업데이트하는 공식입니다.
#
# $\alpha (런닝레이트)$
#
# **기본 공식:**
#
# $$
# W := W - \alpha \frac{\partial}{\partial W} \text{cost}(W)
# $$
#
# ---
#
# ## 3. Full Update Equation (전체 업데이트 수식)
#
# 재정의된 $\text{cost}(W)$를 경사 하강법 공식에 대입하고 $W$에 대해 편미분한 결과입니다.
#
# $$
# W := W - \alpha \frac{\partial}{\partial W} \frac{1}{2m} \sum_{i=1}^{m} (Wx^{(i)} - y^{(i)})^2
# $$
#
# **편미분 적용:**
#
# $$
# W := W - \alpha \frac{1}{2m} \sum_{i=1}^{m} 2(Wx^{(i)} - y^{(i)}) x^{(i)}
# $$
#
# **최종 업데이트 공식:**
#
# $$
# W := W - \alpha \frac{1}{m} \sum_{i=1}^{m} (Wx^{(i)} - y^{(i)}) x^{(i)}
# $$
#
# ---
#
# ### 수식 표기 설명:
#
# * **$W$**: 가중치 (Weight)
# * **$x^{(i)}$**: $i$번째 훈련 데이터의 입력 값 (특징)
# * **$y^{(i)}$**: $i$번째 훈련 데이터의 실제 레이블 (정답)
# * **$m$**: 훈련 데이터의 총 개수
# * **$\alpha$**: 학습률 (Learning Rate)
# * **$Wx^{(i)}$**: $i$번째 데이터에 대한 **예측 값** ($\hat{y}^{(i)}$)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def mse( x, y, w ):
    c = 0
    for i in range( len(x)):
        hx = w*x[i]
        c = c+ (hx-y[i])**2
    return c/len(x)

# %%
def gradient( x, y, w ):
    c = 0
    for i in range( len(x)):
        hx = w*x[i]
        c = c+ (hx-y[i])*x[i]
    return c/len(x)

# %%
x_data = np.array( [1,2,3] )
y_data = np.array( [1,2,3] )

# %%
w = 10 #랜덤하게
for epoch in range(200):
    c = mse( x_data, y_data, w)
    g = gradient( x_data,y_data, w) # w에 대한 접선기울기
    print( epoch+1, "w=", w, "cost=", c, '기울기:', g)
    w = w-0.1*g
  
print("w=", w)
# Out:
# 1 w= 10 cost= 378.0 기울기: 42.0
# 2 w= 5.8 cost= 107.51999999999998 기울기: 22.399999999999995
# 3 w= 3.56 cost= 30.583466666666666 기울기: 11.946666666666667
# 4 w= 2.365333333333333 cost= 8.69929718518518 기울기: 6.371555555555553
# 5 w= 1.7281777777777778 cost= 2.47446675489712 기울기: 3.3981629629629633
# 6 w= 1.3883614814814815 cost= 0.7038483213929583 기울기: 1.8123535802469135
# 7 w= 1.2071261234567903 cost= 0.2002057447517751 기울기: 0.9665885761316879
# 8 w= 1.1104672658436214 cost= 0.05694741184050483 기울기: 0.5155139072702332
# 9 w= 1.0589158751165981 cost= 0.016198374923521403 기울기: 0.2749407505441246
# 10 w= 1.0314218000621858 cost= 0.004607537756023892 기울기: 0.14663506695686687
# 11 w= 1.0167582933664991 cost= 0.0013105885172690224 기울기: 0.07820536904366245
# 12 w= 1.008937756462133 cost= 0.0003727896226898598 기울기: 0.04170953015662023
# 13 w= 1.004766803446471 cost= 0.0001060379371206724 기울기: 0.02224508275019758
# 14 w= 1.002542295171451 cost= 3.0161902114324568e-05 기울기: 0.011864044133438703
# 15 w= 1.0013558907581073 cost= 8.579385490296031e-06 기울기: 0.0063274902045003705
# 16 w= 1.0007231417376572 cost= 2.4403585394623746e-06 기울기: 0.0033746614424004693
# 17 w= 1.000385675593417 cost= 6.941464290019953e-07 기울기: 0.0017998194359460928
# 18 w= 1.0002056936498225 cost= 1.9744609536079287e-07 기울기: 0.0009599036991717972
# 19 w= 1.0001097032799053 cost= 5.616244490256599e-08 기울기: 0.0005119486395580205
# 20 w= 1.0000585084159495 cost= 1.597509543893363e-08 기울기: 0.00027303927443078635
# 21 w= 1.0000312044885065 cost= 4.544027147100321e-09 기울기: 0.00014562094636350054
# 22 w= 1.0000166423938701 cost= 1.292523277397425e-09 기울기: 7.766450472720028e-05
# 23 w= 1.0000088759433974 cost= 3.6765106557353845e-10 기울기: 4.142106918799312e-05
# 24 w= 1.0000047338364786 cost= 1.0457630309680019e-10 기울기: 2.2091236900297535e-05
# 25 w= 1.0000025247127886 cost= 2.974614843652282e-11 기울기: 1.1781993013511757e-05
# 26 w= 1.0000013465134872 cost= 8.461126664488492e-12 기울기: 6.283729606500661e-06
# 27 w= 1.0000007181405266 cost= 2.4067204744183466e-12 기울기: 3.351322457471421e-06
# 28 w= 1.0000003830082809 cost= 6.845782681618235e-13 기울기: 1.787371977165127e-06
# 29 w= 1.0000002042710832 cost= 1.9472448527085553e-13 기울기: 9.532650547446527e-07
# 30 w= 1.0000001089445776 cost= 5.538829787885448e-14 기울기: 5.084080284915397e-07
# 31 w= 1.0000000581037747 cost= 1.575489361658054e-14 기울기: 2.711509485090839e-07
# 32 w= 1.0000000309886798 cost= 4.4813919525692676e-15 기울기: 1.4461383905188066e-07
# 33 w= 1.000000016527296 cost= 1.2747070573345361e-15 기울기: 7.712738122241565e-08
# 34 w= 1.0000000088145578 cost= 3.6258332831368247e-16 기울기: 4.113460261301327e-08
# 35 w= 1.0000000047010975 cost= 1.0313481853667948e-16 기울기: 2.1938455274650437e-08
# 36 w= 1.000000002507252 cost= 2.933612341505031e-17 기울기: 1.170050893210354e-08
# 37 w= 1.000000001337201 cost= 8.344497274162171e-18 기울기: 6.2402714107179236e-09
# 38 w= 1.000000000713174 cost= 2.3735464825145457e-18 기울기: 3.3281451668661552e-09
# 39 w= 1.0000000003803595 cost= 6.751422044227725e-19 기울기: 1.7750108790200632e-09
# 40 w= 1.0000000002028584 cost= 1.920405593646558e-19 기울기: 9.466727401985509e-10
# 41 w= 1.0000000001081912 cost= 5.462493428133877e-20 기울기: 5.048924241653671e-10
# 42 w= 1.000000000057702 cost= 1.5537773320496455e-20 기울기: 2.692760829129763e-10
# 43 w= 1.0000000000307745 cost= 4.419657596231936e-21 기울기: 1.43614305632885e-10
# 44 w= 1.000000000016413 cost= 1.2571515848923574e-21 기울기: 7.659443449862617e-11
# 45 w= 1.0000000000087537 cost= 3.5758710617043957e-22 기울기: 4.0850212101872785e-11
# 46 w= 1.0000000000046687 cost= 1.0171864166944069e-22 기울기: 2.1787312694717304e-11
# 47 w= 1.00000000000249 cost= 2.8933990559698716e-23 기울기: 1.1620038264936738e-11
# 48 w= 1.000000000001328 cost= 8.231253103671774e-24 기울기: 6.197783027535782e-12
# 49 w= 1.0000000000007083 cost= 2.341362175139032e-24 기울기: 3.3055040186506326e-12
# 50 w= 1.0000000000003777 cost= 6.658942698258942e-25 기울기: 1.7628121184998236e-12
# 51 w= 1.0000000000002014 cost= 1.891893061517278e-25 기울기: 9.396187531744242e-13
# 52 w= 1.0000000000001075 cost= 5.389865839559056e-26 기울기: 5.015247476573373e-13
# 53 w= 1.0000000000000573 cost= 1.5315340044413334e-26 기울기: 2.673417043297377e-13
# 54 w= 1.0000000000000306 cost= 4.38172789805011e-27 기울기: 1.4299672557172016e-13
# 55 w= 1.0000000000000164 cost= 1.2599423424554927e-27 기울기: 7.667940356744414e-14
# 56 w= 1.0000000000000087 cost= 3.46129156767911e-28 기울기: 4.0190073491430667e-14
# 57 w= 1.0000000000000047 cost= 1.0355442841244991e-28 기울기: 2.19824158875781e-14
# 58 w= 1.0000000000000024 cost= 2.677196697093809e-29 기울기: 1.117624511455991e-14
# 59 w= 1.0000000000000013 cost= 8.283039504820624e-30 기울기: 6.217248937900877e-15
# 60 w= 1.0000000000000007 cost= 1.791371638939381e-30 기울기: 2.886579864025407e-15
# 61 w= 1.0000000000000004 cost= 9.203377227578472e-31 기울기: 2.0724163126336257e-15
# 62 w= 1.0000000000000002 cost= 3.4512664603419266e-31 기울기: 1.2582527612418441e-15
# 63 w= 1.0 cost= 0.0 기울기: 0.0
# 64 w= 1.0 cost= 0.0 기울기: 0.0
# 65 w= 1.0 cost= 0.0 기울기: 0.0
# 66 w= 1.0 cost= 0.0 기울기: 0.0
# 67 w= 1.0 cost= 0.0 기울기: 0.0
# 68 w= 1.0 cost= 0.0 기울기: 0.0
# 69 w= 1.0 cost= 0.0 기울기: 0.0
# 70 w= 1.0 cost= 0.0 기울기: 0.0
# 71 w= 1.0 cost= 0.0 기울기: 0.0
# 72 w= 1.0 cost= 0.0 기울기: 0.0
# 73 w= 1.0 cost= 0.0 기울기: 0.0
# 74 w= 1.0 cost= 0.0 기울기: 0.0
# 75 w= 1.0 cost= 0.0 기울기: 0.0
# 76 w= 1.0 cost= 0.0 기울기: 0.0
# 77 w= 1.0 cost= 0.0 기울기: 0.0
# 78 w= 1.0 cost= 0.0 기울기: 0.0
# 79 w= 1.0 cost= 0.0 기울기: 0.0
# 80 w= 1.0 cost= 0.0 기울기: 0.0
# 81 w= 1.0 cost= 0.0 기울기: 0.0
# 82 w= 1.0 cost= 0.0 기울기: 0.0
# 83 w= 1.0 cost= 0.0 기울기: 0.0
# 84 w= 1.0 cost= 0.0 기울기: 0.0
# 85 w= 1.0 cost= 0.0 기울기: 0.0
# 86 w= 1.0 cost= 0.0 기울기: 0.0
# 87 w= 1.0 cost= 0.0 기울기: 0.0
# 88 w= 1.0 cost= 0.0 기울기: 0.0
# 89 w= 1.0 cost= 0.0 기울기: 0.0
# 90 w= 1.0 cost= 0.0 기울기: 0.0
# 91 w= 1.0 cost= 0.0 기울기: 0.0
# 92 w= 1.0 cost= 0.0 기울기: 0.0
# 93 w= 1.0 cost= 0.0 기울기: 0.0
# 94 w= 1.0 cost= 0.0 기울기: 0.0
# 95 w= 1.0 cost= 0.0 기울기: 0.0
# 96 w= 1.0 cost= 0.0 기울기: 0.0
# 97 w= 1.0 cost= 0.0 기울기: 0.0
# 98 w= 1.0 cost= 0.0 기울기: 0.0
# 99 w= 1.0 cost= 0.0 기울기: 0.0
# 100 w= 1.0 cost= 0.0 기울기: 0.0
# 101 w= 1.0 cost= 0.0 기울기: 0.0
# 102 w= 1.0 cost= 0.0 기울기: 0.0
# 103 w= 1.0 cost= 0.0 기울기: 0.0
# 104 w= 1.0 cost= 0.0 기울기: 0.0
# 105 w= 1.0 cost= 0.0 기울기: 0.0
# 106 w= 1.0 cost= 0.0 기울기: 0.0
# 107 w= 1.0 cost= 0.0 기울기: 0.0
# 108 w= 1.0 cost= 0.0 기울기: 0.0
# 109 w= 1.0 cost= 0.0 기울기: 0.0
# 110 w= 1.0 cost= 0.0 기울기: 0.0
# 111 w= 1.0 cost= 0.0 기울기: 0.0
# 112 w= 1.0 cost= 0.0 기울기: 0.0
# 113 w= 1.0 cost= 0.0 기울기: 0.0
# 114 w= 1.0 cost= 0.0 기울기: 0.0
# 115 w= 1.0 cost= 0.0 기울기: 0.0
# 116 w= 1.0 cost= 0.0 기울기: 0.0
# 117 w= 1.0 cost= 0.0 기울기: 0.0
# 118 w= 1.0 cost= 0.0 기울기: 0.0
# 119 w= 1.0 cost= 0.0 기울기: 0.0
# 120 w= 1.0 cost= 0.0 기울기: 0.0
# 121 w= 1.0 cost= 0.0 기울기: 0.0
# 122 w= 1.0 cost= 0.0 기울기: 0.0
# 123 w= 1.0 cost= 0.0 기울기: 0.0
# 124 w= 1.0 cost= 0.0 기울기: 0.0
# 125 w= 1.0 cost= 0.0 기울기: 0.0
# 126 w= 1.0 cost= 0.0 기울기: 0.0
# 127 w= 1.0 cost= 0.0 기울기: 0.0
# 128 w= 1.0 cost= 0.0 기울기: 0.0
# 129 w= 1.0 cost= 0.0 기울기: 0.0
# 130 w= 1.0 cost= 0.0 기울기: 0.0
# 131 w= 1.0 cost= 0.0 기울기: 0.0
# 132 w= 1.0 cost= 0.0 기울기: 0.0
# 133 w= 1.0 cost= 0.0 기울기: 0.0
# 134 w= 1.0 cost= 0.0 기울기: 0.0
# 135 w= 1.0 cost= 0.0 기울기: 0.0
# 136 w= 1.0 cost= 0.0 기울기: 0.0
# 137 w= 1.0 cost= 0.0 기울기: 0.0
# 138 w= 1.0 cost= 0.0 기울기: 0.0
# 139 w= 1.0 cost= 0.0 기울기: 0.0
# 140 w= 1.0 cost= 0.0 기울기: 0.0
# 141 w= 1.0 cost= 0.0 기울기: 0.0
# 142 w= 1.0 cost= 0.0 기울기: 0.0
# 143 w= 1.0 cost= 0.0 기울기: 0.0
# 144 w= 1.0 cost= 0.0 기울기: 0.0
# 145 w= 1.0 cost= 0.0 기울기: 0.0
# 146 w= 1.0 cost= 0.0 기울기: 0.0
# 147 w= 1.0 cost= 0.0 기울기: 0.0
# 148 w= 1.0 cost= 0.0 기울기: 0.0
# 149 w= 1.0 cost= 0.0 기울기: 0.0
# 150 w= 1.0 cost= 0.0 기울기: 0.0
# 151 w= 1.0 cost= 0.0 기울기: 0.0
# 152 w= 1.0 cost= 0.0 기울기: 0.0
# 153 w= 1.0 cost= 0.0 기울기: 0.0
# 154 w= 1.0 cost= 0.0 기울기: 0.0
# 155 w= 1.0 cost= 0.0 기울기: 0.0
# 156 w= 1.0 cost= 0.0 기울기: 0.0
# 157 w= 1.0 cost= 0.0 기울기: 0.0
# 158 w= 1.0 cost= 0.0 기울기: 0.0
# 159 w= 1.0 cost= 0.0 기울기: 0.0
# 160 w= 1.0 cost= 0.0 기울기: 0.0
# 161 w= 1.0 cost= 0.0 기울기: 0.0
# 162 w= 1.0 cost= 0.0 기울기: 0.0
# 163 w= 1.0 cost= 0.0 기울기: 0.0
# 164 w= 1.0 cost= 0.0 기울기: 0.0
# 165 w= 1.0 cost= 0.0 기울기: 0.0
# 166 w= 1.0 cost= 0.0 기울기: 0.0
# 167 w= 1.0 cost= 0.0 기울기: 0.0
# 168 w= 1.0 cost= 0.0 기울기: 0.0
# 169 w= 1.0 cost= 0.0 기울기: 0.0
# 170 w= 1.0 cost= 0.0 기울기: 0.0
# 171 w= 1.0 cost= 0.0 기울기: 0.0
# 172 w= 1.0 cost= 0.0 기울기: 0.0
# 173 w= 1.0 cost= 0.0 기울기: 0.0
# 174 w= 1.0 cost= 0.0 기울기: 0.0
# 175 w= 1.0 cost= 0.0 기울기: 0.0
# 176 w= 1.0 cost= 0.0 기울기: 0.0
# 177 w= 1.0 cost= 0.0 기울기: 0.0
# 178 w= 1.0 cost= 0.0 기울기: 0.0
# 179 w= 1.0 cost= 0.0 기울기: 0.0
# 180 w= 1.0 cost= 0.0 기울기: 0.0
# 181 w= 1.0 cost= 0.0 기울기: 0.0
# 182 w= 1.0 cost= 0.0 기울기: 0.0
# 183 w= 1.0 cost= 0.0 기울기: 0.0
# 184 w= 1.0 cost= 0.0 기울기: 0.0
# 185 w= 1.0 cost= 0.0 기울기: 0.0
# 186 w= 1.0 cost= 0.0 기울기: 0.0
# 187 w= 1.0 cost= 0.0 기울기: 0.0
# 188 w= 1.0 cost= 0.0 기울기: 0.0
# 189 w= 1.0 cost= 0.0 기울기: 0.0
# 190 w= 1.0 cost= 0.0 기울기: 0.0
# 191 w= 1.0 cost= 0.0 기울기: 0.0
# 192 w= 1.0 cost= 0.0 기울기: 0.0
# 193 w= 1.0 cost= 0.0 기울기: 0.0
# 194 w= 1.0 cost= 0.0 기울기: 0.0
# 195 w= 1.0 cost= 0.0 기울기: 0.0
# 196 w= 1.0 cost= 0.0 기울기: 0.0
# 197 w= 1.0 cost= 0.0 기울기: 0.0
# 198 w= 1.0 cost= 0.0 기울기: 0.0
# 199 w= 1.0 cost= 0.0 기울기: 0.0
# 200 w= 1.0 cost= 0.0 기울기: 0.0
# w= 1.0
